# %%
import cv2
import os

EPSILON = 0.005
import coco
import yolo
import vgg

repo_dir = project_name = 'COTSDataset' 
part1_single_objects = os.path.join(repo_dir, "Part 1 - Single Objects")
part2_multiple_objects = os.path.join(repo_dir, "Part 2 - Multiple Objects")
part3_complex_background = os.path.join(repo_dir, "Part 3 - Complex Background")

do_display = True
do_save = True

# COCO
coco_output_dir = "COCO_annotations_multiple"
coco_color = (255, 0, 255)

# YOLO
yolo_output_dir = "YOLO_annotations"
yolo_color = (0, 255, 0)

# VGG
vgg_output_dir = "VGG_annotations"
vgg_color = (255, 0, 0)

# %% [markdown]
# **<h2>COCO Annotations</h2>**

# %%
image_id = 0

for image_paths in os.listdir(part3_complex_background):
    if(image_paths == "masks"):
        continue
    mask_paths = os.path.join(part3_complex_background, "masks", image_paths)
    category = image_paths
    for mask_name in os.listdir(mask_paths):
        image = cv2.imread(os.path.join(mask_paths, mask_name))
        coco.annotate((image_id, image_paths+" "+mask_name, image, project_name, category, coco_output_dir),
                      do_display, do_save, annotation_color=coco_color, epsilon=EPSILON,configuration=coco.PA, object_configuration=coco.MO,do_cvt=True)
        image_id += 1
# Out:
#  Annotating image:  booksA_nw_no 1_colour.png
#  Succesfully saved image:  booksA_nw_no 1_colour.png
#
#
# ------------------------------------------------------------------------------------------------------------------------
#
#  Annotating image:  booksA_nw_no 2_colour.png
#  Succesfully saved image:  booksA_nw_no 2_colour.png
#
#
# ------------------------------------------------------------------------------------------------------------------------
#
#  Annotating image:  booksA_nw_no 3_colour.png
#  Succesfully saved image:  booksA_nw_no 3_colour.png
#
#
# ------------------------------------------------------------------------------------------------------------------------
#
#  Annotating image:  booksA_nw_oc 1_colour.png
#  Succesfully saved image:  booksA_nw_oc 1_colour.png
#
#
# ------------------------------------------------------------------------------------------------------------------------
#
#  Annotating image:  booksA_nw_oc 2_colour.png
# ...
